# %%
# Experiment 2: Tone & Style Variation

# Prompt 1: Formal Tone
prompt1 = "Explain Artificial Intelligence and its applications in a formal tone."
output1 = """Artificial Intelligence (AI) refers to the development of computer systems capable of performing tasks that typically require human intelligence. Its applications span healthcare, finance, education, and transportation, enhancing operational efficiency and decision-making processes."""
observation1 = "GPT-4 provides professional, structured, and formal language suitable for reports or articles."

print("Prompt 1:", prompt1)
print("Output 1:", output1)
print("Observation 1:", observation1)
print("\n" + "-"*80 + "\n")

# Prompt 2: Humorous Tone
prompt2 = "Explain AI in a humorous way for beginners."
output2 = """AI is like having a really smart robot friend who never sleeps, doesn’t complain, and can help you figure out everything from your emails to diagnosing diseases. The best part? It doesn’t drink your coffee!"""
observation2 = "GPT-4 uses humor, light examples, and keeps the explanation entertaining."

print("Prompt 2:", prompt2)
print("Output 2:", output2)
print("Observation 2:", observation2)
print("\n" + "-"*80 + "\n")

# Prompt 3: Inspirational Tone
prompt3 = "Write about AI in an inspirational tone."
output3 = """Artificial Intelligence has the power to transform our world, helping humans achieve breakthroughs once thought impossible. By embracing AI, we can solve complex problems, innovate endlessly, and create a future full of opportunities and hope."""
observation3 = "GPT-4 motivates the reader and emphasizes the potential of AI in a positive, uplifting way."

print("Prompt 3:", prompt3)
print("Output 3:", output3)
print("Observation 3:", observation3)
# Out:
# Prompt 1: Explain Artificial Intelligence and its applications in a formal tone.
# Output 1: Artificial Intelligence (AI) refers to the development of computer systems capable of performing tasks that typically require human intelligence. Its applications span healthcare, finance, education, and transportation, enhancing operational efficiency and decision-making processes.
# Observation 1: GPT-4 provides professional, structured, and formal language suitable for reports or articles.
#
# --------------------------------------------------------------------------------
#
# Prompt 2: Explain AI in a humorous way for beginners.
# Output 2: AI is like having a really smart robot friend who never sleeps, doesn’t complain, and can help you figure out everything from your emails to diagnosing diseases. The best part? It doesn’t drink your coffee!
# Observation 2: GPT-4 uses humor, light examples, and keeps the explanation entertaining.
#
# ...
