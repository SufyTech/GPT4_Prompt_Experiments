# %%
# Experiment 1: Basic Prompt Variations

# Prompt 1: Simple Question
prompt1 = "Write a short introduction about Artificial Intelligence."
output1 = """Artificial Intelligence (AI) is the simulation of human intelligence in machines that are programmed to think, learn, and solve problems. AI is applied in healthcare, finance, robotics, and more to improve efficiency and decision-making."""
observation1 = "This prompt is simple. GPT-4 provides a short, beginner-friendly introduction."

print("Prompt 1:", prompt1)
print("Output 1:", output1)
print("Observation 1:", observation1)
print("\n" + "-"*80 + "\n")  # Separator for screenshots

# Prompt 2: Casual Tone
prompt2 = "Explain the impact of AI in healthcare like you're talking to a friend."
output2 = """Hey! So AI in healthcare is pretty amazing. It helps doctors diagnose diseases faster, predicts patient risks, and even assists in surgeries. Basically, it makes healthcare smarter and more efficient for everyone."""
observation2 = "GPT-4 uses casual language, simple examples, and makes the content more relatable."

print("Prompt 2:", prompt2)
print("Output 2:", output2)
print("Observation 2:", observation2)
print("\n" + "-"*80 + "\n")

# Prompt 3: Persuasive Style
prompt3 = "Write a persuasive paragraph about why AI should be adopted in hospitals."
output3 = """Adopting AI in hospitals can save countless lives by improving diagnostic accuracy, optimizing patient care, and reducing human error. With AI, hospitals can operate more efficiently, making healthcare more accessible and effective for everyone."""
observation3 = "GPT-4 focuses on benefits, uses convincing language, and tries to persuade the reader."

print("Prompt 3:", prompt3)
print("Output 3:", output3)
print("Observation 3:", observation3)
# Out:
# Prompt 1: Write a short introduction about Artificial Intelligence.
# Output 1: Artificial Intelligence (AI) is the simulation of human intelligence in machines that are programmed to think, learn, and solve problems. AI is applied in healthcare, finance, robotics, and more to improve efficiency and decision-making.
# Observation 1: This prompt is simple. GPT-4 provides a short, beginner-friendly introduction.
#
# --------------------------------------------------------------------------------
#
# Prompt 2: Explain the impact of AI in healthcare like you're talking to a friend.
# Output 2: Hey! So AI in healthcare is pretty amazing. It helps doctors diagnose diseases faster, predicts patient risks, and even assists in surgeries. Basically, it makes healthcare smarter and more efficient for everyone.
# Observation 2: GPT-4 uses casual language, simple examples, and makes the content more relatable.
#
# --------------------------------------------------------------------------------
#
# ...
