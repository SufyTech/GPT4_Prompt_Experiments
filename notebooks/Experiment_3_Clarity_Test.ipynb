# %%
# Experiment 3: Prompt Clarity Test

# Prompt 1: Vague Prompt
prompt1 = "Tell me about AI."
output1 = """Artificial Intelligence (AI) is the field of computer science that focuses on creating machines capable of intelligent behavior. It includes areas such as machine learning, natural language processing, and robotics."""
observation1 = "GPT-4 provides a general overview, but lacks depth due to vague prompt."

print("Prompt 1:", prompt1)
print("Output 1:", output1)
print("Observation 1:", observation1)
print("\n" + "-"*80 + "\n")

# Prompt 2: Clear Prompt
prompt2 = "Explain AI in healthcare, including benefits and challenges."
output2 = """AI in healthcare helps in early disease detection, personalized treatment plans, and operational efficiency. Challenges include data privacy concerns, high implementation costs, and the need for regulatory compliance."""
observation2 = "GPT-4 delivers more precise and informative content due to a clear prompt."

print("Prompt 2:", prompt2)
print("Output 2:", output2)
print("Observation 2:", observation2)
print("\n" + "-"*80 + "\n")

# Prompt 3: Detailed Prompt
prompt3 = "Explain how AI improves patient outcomes in hospitals, including examples, potential challenges, and future trends."
output3 = """AI improves patient outcomes by enabling early diagnosis through predictive analytics, personalized treatment plans using patient data, and optimizing hospital workflows. Examples include AI-assisted imaging, virtual health assistants, and automated monitoring systems. Challenges include data privacy, integration with existing systems, and regulatory compliance. Future trends involve AI-driven telemedicine, robotic surgery assistance, and continuous learning algorithms for precision healthcare."""
observation3 = "GPT-4 gives a comprehensive and detailed response, showing the importance of precise and detailed prompts."

print("Prompt 3:", prompt3)
print("Output 3:", output3)
print("Observation 3:", observation3)
# Out:
# Prompt 1: Tell me about AI.
# Output 1: Artificial Intelligence (AI) is the field of computer science that focuses on creating machines capable of intelligent behavior. It includes areas such as machine learning, natural language processing, and robotics.
# Observation 1: GPT-4 provides a general overview, but lacks depth due to vague prompt.
#
# --------------------------------------------------------------------------------
#
# Prompt 2: Explain AI in healthcare, including benefits and challenges.
# Output 2: AI in healthcare helps in early disease detection, personalized treatment plans, and operational efficiency. Challenges include data privacy concerns, high implementation costs, and the need for regulatory compliance.
# Observation 2: GPT-4 delivers more precise and informative content due to a clear prompt.
#
# --------------------------------------------------------------------------------
#
# ...
